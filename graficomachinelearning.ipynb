# %% [markdown]
# <a href="https://colab.research.google.com/github/fbb2306/-estudo-banco-de-dados-relacional-/blob/main/graficomachinelearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.mixture import GaussianMixture

#definir uma semente aleatorio para garantir a reprodutibilidade dos resultados
np.random.seed(70)

#criacao de dois conjuntos de dados ficticios, cada um com uma distribuicao gausiana
data1= np.random.normal(loc=-6, scale=1, size= 500)
data2= np.random.normal(loc=7, scale=1, size= 900)

#combina os dois conjuntos de dados para formar um unico conjunto
#data= np.concatenate([data1, data2])

#visualiza o conjunto de dados original com um grafico
plt.hist(data, bins=30, density=True)
plt.title("Dados Originais")
plt.show()

#cria e treina um modelo de mistura gausiana
gmm = GaussianMixture(n_components=2)
#ajusta o modelo de dados
gmm.fit(data.reshape(-1, 1))

#usando o treinamento para gerar 1000 novos pontos de dados
samples = gmm.sample(1000)[0]


fig, axs = plt.subplots(1, 2, figsize=(12, 5))

plt.hist(samples, bins=30, density=True, alpha = .5, color = 'green', label= 'Dados misturados')
plt.hist(data, bins=30, density=True, alpha = .5, color = 'red', label= 'Dados Originais')
plt.title('Comparação: Dado 1 vs Dado 2')
plt.legend()
plt.show()
